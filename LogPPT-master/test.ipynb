# %%
from logppt.evaluation.utils.common import correct_templates_and_update_files

# %%
import pandas as pd
import csv

df = pd.read_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_structured_ORIG.csv', sep="@")
event_tokenized = pd.read_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_EventTemplate_formatted.log', sep="@", error_bad_lines=False, quoting=csv.QUOTE_NONE)
df["EventTemplate"] = event_tokenized.values
df["EventId"] = df.apply(lambda row: "E"+str(row.name), axis=1)
df.to_csv("C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_structured_corrected.csv")

# %%
df = pd.read_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_structured_ORIG.csv')
#event_tokenized = pd.read_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_EventTemplate_formatted.log', sep="@", error_bad_lines=False, quoting=csv.QUOTE_NONE)
df["EventTemplate"] = df["Content"].values
df["EventId"] = df.apply(lambda row: "E"+str(row.name), axis=1)
df.to_csv("C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_structured.csv")

# %%
"""    
:param dir_path: a directory to write the structured log and template files
:param log_file_basename: a base file name (ex: BGL_2k.log)
:param inplace: whether the update is performed on the existing file or not
"""
dir_path = "C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\tmp"
log_file_basename = "C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log"
correct_templates_and_update_files(dir_path, log_file_basename, inplace=False)

# %%
dd = pd.read_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_structured_corrected.csv')
dd["EventTemplate"].to_csv("C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_EventTemplate.csv", index=False)

# %%
df.shape
# Out:
# (11709, 1)

# %%
import csv
"""
https://stackoverflow.com/questions/33161769/not-reading-all-rows-while-importing-csv-into-pandas-dataframe
https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-bad-lines
By default, read_csv uses the Excel dialect and treats the double quote as the quote character, which causes it to fail when it finds a newline before it finds the closing double quote.
"""
tt = pd.read_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\traceFE.log_EventTemplate_formatted.log', sep="@", error_bad_lines=False, quoting=csv.QUOTE_NONE)
tt.shape
# Out:
# (11709, 1)

# %%
tt.to_csv('C:\\Users\\fontanesio\\Documents\\pythonScripts\\progetti\\personali\\LogPPT-master\\logs\\traceFE\\test.log', index=False)

# %%
11709 - 11675
# Out:
# 34
